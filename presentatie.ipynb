# %% [markdown]
# ## Woordgebruik in de tweede kamer
#
# ##### *Man-vrouw verhoudingen in de politiek*
#
# Anh, Peter, Larissa, Coen

# %% [markdown]
# ## Onderzoeksvraag
# ** *In hoeverre verschillen mannen en vrouwen in woordgebruik binnen de Nederlandse politiek?* **

# %% [markdown]
# ## Wat hebben we gedaan?

# %% [markdown]
# - Data Wilders2014 - TK_Handelingen
#     - http://overheid.nl
#     - http://maartenmarx.nl/teaching/DataScience/Data/WildersXMLassignment
#
#
# - Geslacht en verhoudingen hiertussen
#
# - Spreektijd - aantal gesproken woorden
#
# - Woordenschat - aantal unieke woorden per politicus
#
# - Stopwoorden - nltk corpus & eigen lijst
#
# - Wordcloud

# %% [markdown]
# ## Hoe hebben we dat gedaan?

# %% [markdown]
# ##### *Methode*
# * Nieuwe pandas dataframe
# * Sprekers
# * Partijen
# * Geslacht om Man/Vrouw te onderscheiden
# * Gesproken text per spreker
# * Aantal woorden tellen
# * Unieke woorden ophalen
# * Visualiseren

# %% [markdown]
# ## Hoe ziet dat eruit?

# %%
from IPython.display import Image
Image(filename='df_whole.png')

# %% [markdown]
# ## Man/vrouw verhouding
# * Man/vrouw verhouding per jaar
# * Geen significant verschil
# * dataframe geordend op jaar en man/vrouw

# %%
Image (filename = 'MVuniek.png')

# %%
Image (filename = 'piechartsYear.png')

# %% [markdown]
# # Aantal woorden
#
# ## Top 50 meest spraakzame mannen en vrouwen
#
# * De eerste stap

# %%
Image (filename = 'top50.png')

# %% [markdown]
# ## Totaal aantal woorden per jaar man/vrouw
# * representatiever beeld, maar zegt nog niks over de aantallen sprekers en gemiddeldes.

# %%
Image (filename = 'totalwoordenjaar.png')

# %% [markdown]
# ## Gemiddelde aantal woorden per jaar man/vrouw
# * Voor een duidelijk beeld hebben we de gemiddeldes genomen

# %%
Image (filename = 'gemiddelde.png')

# %% [markdown]
# # Conclusie - Verhoudingen man/vrouw
# * Om een echt duidelijk beeld te krijgen over de verschillen tussen mannen en vrouwen hebben we naar de verhoudingen tussen mannen en vrouwen per jaar gekeken.

# %%
Image (filename = 'verhouding.png')

# %% [markdown]
# ## Extra: Wordclouds
#
# * Meest voorkomende woorden
# * Filteren
#     * Stopwords (nltk)
#     * Stopwords (eigen lijst)
# * Stoppen bij eerste interessante uitkomst

# %%
Image(filename='wordcloud.png')

# %% [markdown]
# ## Wat we jullie willen meegeven
#
# ##### *afsluiting*
#
# - Snel testen op kleine dataset?
# - Gebruik random sampling!

# %% [markdown]
# ### want anders...

# %%
Image(filename='random_sampling.png')

# %% [markdown]
# # Bedankt voor jullie aandacht
